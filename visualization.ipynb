# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data =pd.DataFrame({
    'state':['UP','AP','MP','Rajasthan','Bihar','Maharashtra'],
    'population':[800,300,600,400,500,600],
    'rainfall':[39,65,78,40,10,20],
    'temperature':[34,26,22,25,30,32],
    'status':['A','B','A','A','B','A']
})

# %%
data
# Out:
#          state  population  rainfall  temperature status
# 0           UP         800        39           34      A
# 1           AP         300        65           26      B
# 2           MP         600        78           22      A
# 3    Rajasthan         400        40           25      A
# 4        Bihar         500        10           30      B
# 5  Maharashtra         600        20           32      A

# %%
data['state']
# Out:
# 0             UP
# 1             AP
# 2             MP
# 3      Rajasthan
# 4          Bihar
# 5    Maharashtra
# Name: state, dtype: object

# %%
data[['state','temperature']]
# Out:
#          state  temperature
# 0           UP           34
# 1           AP           26
# 2           MP           22
# 3    Rajasthan           25
# 4        Bihar           30
# 5  Maharashtra           32

# %%
data
# Out:
#          state  population  rainfall  temperature status
# 0           UP         800        39           34      A
# 1           AP         300        65           26      B
# 2           MP         600        78           22      A
# 3    Rajasthan         400        40           25      A
# 4        Bihar         500        10           30      B
# 5  Maharashtra         600        20           32      A

# %% [markdown]
# visualization
# -line plot
# -area plot
# -bar plot
# -histogram
# -pie chart
# -box plot
# -scatter plot
# -bubble plot

# %%
data['population'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:>

# %%
data['population'].plot(figsize=(12,4), style='sr--', markersize=20, linewidth=2, title='population')
# Out:
# <AxesSubplot:title={'center':'population'}>

# %%
data['population'].plot(figsize=(12,4), style='sr--', 
                   markersize=15, linewidth=2, 
                   title='Population of state',
                   xlable='states',
                   ylable='population')
plt.xticks(data.index, data['state'],rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Akanksha\Documents\Data Science\visualization.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> data['population'].plot(figsize=(12,4), style='sr--',
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a>                    markersize=15, linewidth=2,
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>                    title='Population of state',
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>                    xlable='states',
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>                    ylable='population')
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> plt.xticks(data.index, data['state'],rotation=45)
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> plt.show()
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1226, in LinePlot._make_plot(self)
#    1223 label = self._mark_right_label(label, index=i)
#    1224 kwds["label"] = label
# -> 1226 newlines = plotf(
#    1227     ax,
#    1228     x,
#    1229     y,
#    1230     style=style,
#    1231     column_num=i,
#    1232     stacking_id=stacking_id,
#    1233     is_errorbar=is_errorbar,
#    1234     **kwds,
#    1235 )
#    1236 self._append_legend_handles_labels(newlines[0], label)
#    1238 if self._is_ts_plot():
#    1239
#    1240     # reset of xlim should be used for ts data
#    1241     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1256, in LinePlot._plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1254     cls._initialize_stacker(ax, stacking_id, len(y))
#    1255 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1256 lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1257 cls._update_stacker(ax, stacking_id, y)
#    1258 return lines
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:91, in register_pandas_matplotlib_converters.<locals>.wrapper(*args, **kwargs)
#      88 @functools.wraps(func)
#      89 def wrapper(*args, **kwargs):
#      90     with pandas_converters():
# ---> 91         return func(*args, **kwargs)
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:755, in MPLPlot._plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     752 else:
#     753     # prevent style kwarg from going to errorbar, where it is unsupported
#     754     args = (x, y, style) if style is not None else (x, y)
# --> 755     return ax.plot(*args, **kwds)
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\axes\_axes.py:1635, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1393 """
#    1394 Plot y versus x as lines and/or markers.
#    1395
#    (...)
#    1632 (``'green'``) or hex strings (``'#008000'``).
#    1633 """
#    1634 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636 for line in lines:
#    1637     self.add_line(line)
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\axes\_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\axes\_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\axes\_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\axes\_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\lines.py:393, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     389 self.set_markeredgewidth(markeredgewidth)
#     391 # update kwargs before updating data to give the caller a
#     392 # chance to init axes (and hence unit support)
# --> 393 self.update(kwargs)
#     394 self.pickradius = pickradius
#     395 self.ind_offset = 0
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\matplotlib\artist.py:1067, in Artist.update(self, props)
#    1065             func = getattr(self, f"set_{k}", None)
#    1066             if not callable(func):
# -> 1067                 raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                      f"has no property {k!r}")
#    1069             ret.append(func(v))
#    1070 if ret:
#
# AttributeError: 'Line2D' object has no property 'xlable'

# %%
data['rainfall'].plot(kind='area', figsize=(12,4), color='red', alpha=.5, title='Rainfall in states')
data['rainfall'].plot(style='ok', markerfacecolor='black')
plt.xticks(data.index,data['state'])
plt.show()

# %%
data['rainfall'].plot(kind='area', figsize=(12,4), color='red', alpha=.1, title='Rainfall in states')
data['rainfall'].plot(kind='bar', color='green', alpha=.5, width=.2)
# Out:
# <AxesSubplot:title={'center':'Rainfall in states'}>

# %%
data
# Out:
#          state  population  rainfall  temperature status
# 0           UP         800        39           34      A
# 1           AP         300        65           26      B
# 2           MP         600        78           22      A
# 3    Rajasthan         400        40           25      A
# 4        Bihar         500        10           30      B
# 5  Maharashtra         600        20           32      A

# %%
data['rainfall'].plot(kind='bar', color='pink', alpha=.5)
plt.ylim(0,100)
for i in range(len(data['rainfall'])):
    plt .text(i, data['rainfall'][i], data['rainfall'][i], ha='center', va='bottom')

# %%
graph=data['rainfall'].plot(kind='bar', color='green', alpha=.5)
plt.ylim(0,100)
graph.bar_label(graph.containers[0], label_type='edge')
plt.show()

# %%
ax=data[['temperature','rainfall']].plot(kind='bar', figsize=(12,4), width=.8, color=['red','blue'], alpha=.8)
ax.set_xticklabels(data['state'])
ax.bar_label(ax.containers[0], label_type='center', padding=3)
ax.bar_label(ax.containers[1], label_type='center', padding=3, color='white')
plt.show()

# %%
data
# Out:
#          state  population  rainfall  temperature status
# 0           UP         800        39           34      A
# 1           AP         300        65           26      B
# 2           MP         600        78           22      A
# 3    Rajasthan         400        40           25      A
# 4        Bihar         500        10           30      B
# 5  Maharashtra         600        20           32      A

# %%
data.population.plot(kind='pie', figsize=(5,5), autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='population'>

# %%
data.population.plot(kind='pie' ,figsize=(5,5),
                    autopct='%.1f%%', colors=['r', 'g','b','c','m','y'],
                    startangle=90)
# Out:
# <AxesSubplot:ylabel='population'>

# %%
data.population.plot(kind='pie' ,figsize=(5,5),
                    autopct='%.1f%%', explode=[0,0,0.1,0,0,0.1],)
# Out:
# <AxesSubplot:ylabel='population'>

# %%
data.population.plot(kind='pie' ,figsize=(5,5),
                    autopct='%.1f%%', explode=[0,0,0.1,0,0,0.1],
                    wedgeprops=dict(width=.2, edgecolor='k'),
                    pctdistance=.8)
plt.legend(bbox_to_anchor=(1,1))

# %%
fig, ax=plt.subplots(1,2, figsize=(12,4))
data.ststus.value_counts().plot(kind='pie', autopct='%.1f%%', ax=ax[0])
data.population.plot(kind='bar', ax=ax[1])
ax[0].set_title('piechart')
ax[1].set_title('barchart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Akanksha\Documents\Data Science\visualization.ipynb Cell 22 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> fig, ax=plt.subplots(1,2, figsize=(12,4))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> data.ststus.value_counts().plot(kind='pie', autopct='%.1f%%', ax=ax[0])
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> data.population.plot(kind='bar', ax=ax[1])
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a> ax[0].set_title('piechart')
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ststus'

# %%
x=np.random.normal(0,10,1000)
plt.hist(x, bins=20)
plt.show()

# %%
data.temperature.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='box', subplots=True, figsize=(12,4))
plt.show()

# %% [markdown]
# Bivariate

# %%
data.plot(kind='scatter', x='temperature', y='rainfall', figsize=(10,4),
          marker='h' , s= 'population',c='population', cmap='cool')
plt.xlim(20,40)
plt.ylim(-10,100)
plt.show()

# %%
data.plot(kind='bar', stacked=True, figsize=(12,4))
plt.show()

# %%
pokemon=pd.read_csv('pokemon.csv', index_col=0)
pokemon.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon.plot(kind='scatter', x='HP', y='Attack', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
pokemon.plot(kind='scatter', x='HP', y='Attack', figsize=(6,6), c='Attack', cmap='cool')
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
pokemon.plot(kind='scatter', x='HP', y='Attack', figsize=(6,6),
            c='Attack', cmap='cool', s='HP', alpha=.5, edgecolor='k')
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Attack'>

# %%
fig, ax= plt.subplots(1,4, figsize=(12,4))
cols=['HP','Attack', 'Defence','Speed']
for i in range(4):
    pokemon.plot(kind='scatter', x='sp.Attack', y=cols[i], ax=ax[i])
    ax[i].set_title(cols[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Defence'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Akanksha\Documents\Data Science\visualization.ipynb Cell 33 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> cols=['HP','Attack', 'Defence','Speed']
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> for i in range(4):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a>     pokemon.plot(kind='scatter', x='Attack', y=cols[i], ax=ax[i])
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X44sZmlsZQ%3D%3D?line=4'>5</a>     ax[i].set_title(cols[i])
#       <a href='vscode-notebook-cell:/c%3A/Users/Akanksha/Documents/Data%20Science/visualization.ipynb#X44sZmlsZQ%3D%3D?line=5'>6</a> plt.show()
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_core.py:917, in PlotAccessor.__call__(self, *args, **kwargs)
#     915 if kind in self._dataframe_kinds:
#     916     if isinstance(data, ABCDataFrame):
# --> 917         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918     else:
#     919         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1116, in ScatterPlot._make_plot(self)
#    1112 else:
#    1113     label = None
#    1114 scatter = ax.scatter(
#    1115     data[x].values,
# -> 1116     data[y].values,
#    1117     c=c_values,
#    1118     label=label,
#    1119     cmap=cmap,
#    1120     norm=norm,
#    1121     **self.kwds,
#    1122 )
#    1123 if cb:
#    1124     cbar_label = c if c_is_column else ""
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Akanksha\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Defence'
